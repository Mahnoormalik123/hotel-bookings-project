# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# !pip install folium
import folium
from folium.plugins import HeatMap
import plotly.express as px

plt.style.use('fivethirtyeight')
# plt.style.use('ggplot')
# %matplotlib inline
pd.set_option('display.max_columns', 32)

# %%
df = pd.read_csv('hotel_bookings.csv')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df["arrival_date_month"].value_counts()
# Out:
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64

# %%
df["hotel"].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
df.shape
# Out:
# (81537, 32)

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
null = pd.DataFrame({'Null Values' : df.isna().sum(), 'Percentage Null Values' : (df.isna().sum()) / (df.shape[0]) * (100)})
null
# Out:
#                                 Null Values  Percentage Null Values
# hotel                                     0                0.000000
# is_canceled                               0                0.000000
# lead_time                                 0                0.000000
# arrival_date_year                         0                0.000000
# arrival_date_month                        0                0.000000
# arrival_date_week_number                  0                0.000000
# arrival_date_day_of_month                 0                0.000000
# stays_in_weekend_nights                   0                0.000000
# stays_in_week_nights                      0                0.000000
# adults                                    0                0.000000
# children                                  4                0.003350
# babies                                    0                0.000000
# meal                                      0                0.000000
# ...

# %%
msno.bar(df)
plt.show()

# %%
# dropping company column and make a new dataframe df
df.drop(['company'], axis=1)
# filling the agent missing values with 0
df['agent'].fillna(0, inplace=True)
# droping the country missing rows
df.dropna(subset=['country'], inplace=True)
# replacing the missing children values with 0
df['children'].fillna(0, inplace=True)

# %%
df.shape
# Out:
# (118902, 32)

# %%
#major guests are coming from:
arrived= df[df["is_canceled"]==0]
arrived.head(15)
arrived["country"].value_counts(ascending=False).head(5)
# Out:
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
# Name: country, dtype: int64

# %%
#HOW MUCH GUESTS PAY FOR ROOM PER NIGHT
print(df['adr'])
average_nightly_rate = df['adr'].mean()
print(f'The average nightly rate for all bookings is: {average_nightly_rate}')
# Out:
# 0           0.00
# 1           0.00
# 2          75.00
# 3          75.00
# 4          98.00
#            ...
# 119385     96.14
# 119386    225.43
# 119387    157.71
# 119388    104.40
# 119389    151.20
# Name: adr, Length: 118902, dtype: float64
# The average nightly rate for all bookings is: 102.00080763990515

# %%
#MOST BUSY MONTHS:
bookings_per_month= bookings_per_month.sort_values(ascending=False)
print("Number of bookings per month:")
print(bookings_per_month)
# Out:
# Number of bookings per month:
# arrival_date_month
# August       13856
# July         12628
# May          11779
# October      11095
# April        11045
# June         10927
# September    10467
# March         9739
# February      8012
# November      6752
# December      6728
# January       5874
# dtype: int64

# %%
#HOW MUCH PRICE VARY PER NIGHT OVER THE YEAR
adr_per_night = df.groupby('arrival_date')['adr'].mean()
print(adr_per_night)
# Out:
# arrival_date
# 2015-07-01     93.602797
# 2015-07-02     82.205484
# 2015-07-03     97.183036
# 2015-07-04     85.582273
# 2015-07-05    100.002642
#                  ...
# 2017-08-27    153.051782
# 2017-08-28    151.281611
# 2017-08-29    144.655440
# 2017-08-30    150.541348
# 2017-08-31    150.616567
# Name: adr, Length: 793, dtype: float64

# %%
#which country has the higher number of reservations in the city hotel:
highest_reservations_country = reservations_by_country.idxmax()
print(f"The country with the highest number of reservations in the City Hotel is: {highest_reservations_country}")
# Out:
# The country with the highest number of reservations in the City Hotel is: PRT

# %%
#average duration of stay :
df['total_nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
average_duration_of_stay = df['total_nights'].mean()
print(f"The average duration of stay is: {average_duration_of_stay:} nights")
# Out:
# The average duration of stay is: 3.4310272325108073 nights

# %%
#hotel wise night stay duration:
df['total_nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
average_duration_by_hotel = df.groupby('hotel')['total_nights'].mean()
print("Average duration of stay for each hotel:")
print(average_duration_by_hotel)
# Out:
# Average duration of stay for each hotel:
# hotel
# City Hotel      2.978236
# Resort Hotel    4.337913
# Name: total_nights, dtype: float64

# %%
#which hotel has more cancellations:
cancellation_rate_by_hotel = df.groupby('hotel')['is_canceled'].mean()
print("Cancellation rate for each hotel:")
print(cancellation_rate_by_hotel)
# Out:
# Cancellation rate for each hotel:
# hotel
# City Hotel      0.417119
# Resort Hotel    0.279750
# Name: is_canceled, dtype: float64
